# %%
import pandas as pd

# %% [markdown]
# ## Загрузка данных и объединение таблиц

# %%
salary_list = pd.read_html('https://worldpopulationreview.com/country-rankings/median-income-by-country')
salary = pd.DataFrame(salary_list[0])
salary.head()
# Out:
#                 Country Median Income Mean Income GDP Per Capita (PPP)  \
# 0            Luxembourg       $26,321     $31,376             $124,590
# 1  United Arab Emirates       $24,292     $27,017              $70,089
# 2                Norway       $22,684     $25,272              $70,005
# 3           Switzerland       $21,490     $25,787              $72,376
# 4         United States       $19,306     $25,332              $65,297
#
#    2021 Population
# 0           634814
# 1          9991089
# 2          5465630
# 3          8715494
# 4        332915073

# %%
salary['Median Income'] = salary['Median Income'].str.replace(',','')
salary['Median Income'] = salary['Median Income'].str.replace('$','')
salary['Median Income'] = pd.to_numeric(salary['Median Income'], downcast="float")
salary = salary[['Country', 'Median Income']]
salary.head()
# Out:
# <ipython-input-169-ad97679f4ccc>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   salary['Median Income'] = salary['Median Income'].str.replace('$','')
#                 Country  Median Income
# 0            Luxembourg        26321.0
# 1  United Arab Emirates        24292.0
# 2                Norway        22684.0
# 3           Switzerland        21490.0
# 4         United States        19306.0

# %%
netflix_subscription = pd.read_csv("/Users/arturarakelan/Downloads/archive-3/Netflix subscription fee Dec-2021.csv")
netflix_subscription.head()
# Out:
#   Country_code    Country  Total Library Size  No. of TV Shows  No. of Movies  \
# 0           ar  Argentina                4760             3154           1606
# 1           au  Australia                6114             4050           2064
# 2           at    Austria                5640             3779           1861
# 3           be    Belgium                4990             3374           1616
# 4           bo    Bolivia                4991             3155           1836
#
#    Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 0                        3.74                           6.30
# 1                        7.84                          12.12
# 2                        9.03                          14.67
# 3                       10.16                          15.24
# 4                        7.99                          10.99
#
#    Cost Per Month - Premium ($)
# 0                          9.26
# 1                         16.39
# 2                         20.32
# 3                         20.32
# 4                         13.99

# %%
continent = pd.read_html('https://statisticstimes.com/geography/countries-by-continents.php')
continent = continent[2]
continent = continent[['Country or Area', 'ISO-alpha3 Code', 'Continent']]
continent.columns = ['Country', 'Country_code', 'Continent']
continent.head()
# Out:
#           Country Country_code Continent
# 0     Afghanistan          AFG      Asia
# 1   Åland Islands          ALA    Europe
# 2         Albania          ALB    Europe
# 3         Algeria          DZA    Africa
# 4  American Samoa          ASM   Oceania

# %%
currencies = pd.read_html('https://fxtop.com/en/countries-currencies.php')
currencies = currencies[24]
currencies = currencies[['country', 'Currency']]
currencies.columns = ['Country', 'Currency']
currencies.head()
# Out:
#           Country            Currency
# 0     Afghanistan  AFN Afghan Afghani
# 1         Albania    ALL Albanian lek
# 2         Algeria  DZD Algerian dinar
# 3  American Samoa       USD US dollar
# 4         Andorra            EUR Euro

# %%
df_netflix_subs = pd.merge(netflix_subscription, salary, how='left', on='Country')
df_netflix_subs.head()
# Out:
#   Country_code    Country  Total Library Size  No. of TV Shows  No. of Movies  \
# 0           ar  Argentina                4760             3154           1606
# 1           au  Australia                6114             4050           2064
# 2           at    Austria                5640             3779           1861
# 3           be    Belgium                4990             3374           1616
# 4           bo    Bolivia                4991             3155           1836
#
#    Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 0                        3.74                           6.30
# 1                        7.84                          12.12
# 2                        9.03                          14.67
# 3                       10.16                          15.24
# 4                        7.99                          10.99
#
#    Cost Per Month - Premium ($)  Median Income
# 0                          9.26         5319.0
# 1                         16.39        17076.0
# 2                         20.32        18405.0
# 3                         20.32        16157.0
# 4                         13.99         3631.0

# %%
df_continent = pd.merge(df_netflix_subs, continent, how='left', on='Country')
df_continent.head()
# Out:
#   Country_code_x    Country  Total Library Size  No. of TV Shows  \
# 0             ar  Argentina                4760             3154
# 1             au  Australia                6114             4050
# 2             at    Austria                5640             3779
# 3             be    Belgium                4990             3374
# 4             bo    Bolivia                4991             3155
#
#    No. of Movies  Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 0           1606                        3.74                           6.30
# 1           2064                        7.84                          12.12
# 2           1861                        9.03                          14.67
# 3           1616                       10.16                          15.24
# 4           1836                        7.99                          10.99
#
#    Cost Per Month - Premium ($)  Median Income Country_code_y      Continent
# 0                          9.26         5319.0            ARG  South America
# 1                         16.39        17076.0            AUS        Oceania
# 2                         20.32        18405.0            AUT         Europe
# 3                         20.32        16157.0            BEL         Europe
# 4                         13.99         3631.0            NaN            NaN

# %%
df_all = pd.merge(df_continent, currencies, how='left', on='Country')
df_all.head()
# Out:
#   Country_code_x    Country  Total Library Size  No. of TV Shows  \
# 0             ar  Argentina                4760             3154
# 1             au  Australia                6114             4050
# 2             at    Austria                5640             3779
# 3             be    Belgium                4990             3374
# 4             bo    Bolivia                4991             3155
#
#    No. of Movies  Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 0           1606                        3.74                           6.30
# 1           2064                        7.84                          12.12
# 2           1861                        9.03                          14.67
# 3           1616                       10.16                          15.24
# 4           1836                        7.99                          10.99
#
#    Cost Per Month - Premium ($)  Median Income Country_code_y      Continent  \
# 0                          9.26         5319.0            ARG  South America
# 1                         16.39        17076.0            AUS        Oceania
# 2                         20.32        18405.0            AUT         Europe
# 3                         20.32        16157.0            BEL         Europe
# 4                         13.99         3631.0            NaN            NaN
#
#                 Currency
# 0     ARS Argentine peso
# 1  AUD Australian dollar
# 2               EUR Euro
# 3               EUR Euro
# 4          BOB Boliviano

# %% [markdown]
# ## Корреляция между доходом и ценой подписки

# %%
corr_ = df[['Median Income', 'Cost Per Month - Basic ($)', 'Cost Per Month - Standard ($)','Cost Per Month - Premium ($)']].corr()
corr_.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_e47d4_row0_col0,#T_e47d4_row1_col1,#T_e47d4_row2_col2,#T_e47d4_row3_col3{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_e47d4_row0_col1,#T_e47d4_row0_col2,#T_e47d4_row0_col3,#T_e47d4_row1_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_e47d4_row1_col2{
#             background-color:  #f7b79b;
#             color:  #000000;
#         }#T_e47d4_row1_col3{
#             background-color:  #96b7ff;
#             color:  #000000;
#         }#T_e47d4_row2_col0{
#             background-color:  #9abbff;
#             color:  #000000;
#         }#T_e47d4_row2_col1{
#             background-color:  #f39475;
#             color:  #000000;
#         }#T_e47d4_row2_col3{
#             background-color:  #d1493f;
#             color:  #f1f1f1;
#         }#T_e47d4_row3_col0{
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }#T_e47d4_row3_col1{
#             background-color:  #efcebd;
#             color:  #000000;
#         }#T_e47d4_row3_col2{
#             background-color:  #cc403a;
#             color:  #f1f1f1;
#         }</style><table id="T_e47d4_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Median Income</th>        <th class="col_heading level0 col1" >Cost Per Month - Basic ($)</th>        <th class="col_heading level0 col2" >Cost Per Month - Standard ($)</th>        <th class="col_heading level0 col3" >Cost Per Month - Premium ($)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e47d4_level0_row0" class="row_heading level0 row0" >Median Income</th>
#                         <td id="T_e47d4_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_e47d4_row0_col1" class="data row0 col1" >0.570032</td>
#                         <td id="T_e47d4_row0_col2" class="data row0 col2" >0.693433</td>
#                         <td id="T_e47d4_row0_col3" class="data row0 col3" >0.752591</td>
#             </tr>
#             <tr>
#                         <th id="T_e47d4_level0_row1" class="row_heading level0 row1" >Cost Per Month - Basic ($)</th>
#                         <td id="T_e47d4_row1_col0" class="data row1 col0" >0.570032</td>
#                         <td id="T_e47d4_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_e47d4_row1_col2" class="data row1 col2" >0.898535</td>
#                         <td id="T_e47d4_row1_col3" class="data row1 col3" >0.820914</td>
#             </tr>
#             <tr>
#                         <th id="T_e47d4_level0_row2" class="row_heading level0 row2" >Cost Per Month - Standard ($)</th>
#                         <td id="T_e47d4_row2_col0" class="data row2 col0" >0.693433</td>
#                         <td id="T_e47d4_row2_col1" class="data row2 col1" >0.898535</td>
#                         <td id="T_e47d4_row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_e47d4_row2_col3" class="data row2 col3" >0.978768</td>
#             </tr>
#             <tr>
#                         <th id="T_e47d4_level0_row3" class="row_heading level0 row3" >Cost Per Month - Premium ($)</th>
#                         <td id="T_e47d4_row3_col0" class="data row3 col0" >0.752591</td>
#                         <td id="T_e47d4_row3_col1" class="data row3 col1" >0.820914</td>
#                         <td id="T_e47d4_row3_col2" class="data row3 col2" >0.978768</td>
#                         <td id="T_e47d4_row3_col3" class="data row3 col3" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
df.plot.scatter(x='Median Income', y='Cost Per Month - Basic ($)')
df.plot.scatter(x='Median Income', y='Cost Per Month - Standard ($)')
df.plot.scatter(x='Median Income', y='Cost Per Month - Premium ($)')
# Out:
# <AxesSubplot:xlabel='Median Income', ylabel='Cost Per Month - Premium ($)'>

# %% [markdown]
# ## Расчет средних

# %%
df_all.groupby(by = 'Currency').mean()[['Cost Per Month - Basic ($)', 'Cost Per Month - Standard ($)', 'Cost Per Month - Premium ($)']]
# Out:
#                         Cost Per Month - Basic ($)  \
# Currency
# ARS Argentine peso                         3.74000
# AUD Australian dollar                      7.84000
# BGN Bulgarian lev                          9.03000
# BOB Boliviano                              7.99000
# BRL Brazilian real                         4.61000
# CAD Canadian dollar                        7.91000
# CHF Swiss franc                           12.88000
# CLP Chilean peso                           7.07000
# COP Colombian peso                         4.31000
# CRC Costa Rican colon                      8.99000
# DKK Danish krone                          12.00000
# EUR Euro                                   9.17125
# GIP Gibraltar pound                        9.03000
# GTQ Guatemalan quetzal                     7.99000
# HKD Hong Kong dollar                       8.08000
# HNL Honduran lempira                       7.99000
# HRK Croatian kuna                          9.03000
# HUF Hungarian forint                       7.64000
# IDR Indonesian rupiah                      8.36000
# ILS Israeli new shekel                    10.56000
# INR Indian rupee                           2.64000
# ISK Icelandic króna                        9.03000
# JPY Japanese yen                           8.73000
# KRW South Korean won                       8.07000
# LTL Lithuanian litas                       9.03000
# MDL Moldovan leu                           9.03000
# MXN Mexican peso                           6.62000
# MYR Malaysian ringgit                      8.29000
# NOK Norwegian krone                        9.94000
# NZD New Zealand dollar                     8.80000
# PEN Peruvian nuevo sol                     6.11000
# PHP Philippine peso                        7.35000
# PLN Polish zloty                           7.13000
# PYG Paraguayan guaraní                     8.29000
# RON Romanian new Leu                       9.03000
# SEK Swedish krona                         10.90000
# SGD Singapore dollar                       9.51000
# THB Thai baht                              8.34000
# TRY Turkish lira                           1.97000
# TWD New Taiwan dollar                      9.74000
# UAH Ukrainian hryvnia                      5.64000
# USD US dollar                              8.49000
# UYU Urugayan peso                          8.99000
# VES sovereign bolivar                      7.99000
# ZAR South African rand                     6.26000
#
#                         Cost Per Month - Standard ($)  \
# Currency
# ARS Argentine peso                           6.300000
# AUD Australian dollar                       12.120000
# BGN Bulgarian lev                           11.290000
# BOB Boliviano                               10.990000
# BRL Brazilian real                           7.110000
# CAD Canadian dollar                         11.870000
# CHF Swiss franc                             20.460000
# CLP Chilean peso                             9.910000
# COP Colombian peso                           6.860000
# CRC Costa Rican colon                       12.990000
# DKK Danish krone                            15.040000
# EUR Euro                                    13.684375
# GIP Gibraltar pound                         14.670000
# GTQ Guatemalan quetzal                      10.990000
# HKD Hong Kong dollar                        10.000000
# HNL Honduran lempira                        10.990000
# HRK Croatian kuna                           11.290000
# HUF Hungarian forint                        10.710000
# IDR Indonesian rupiah                       10.660000
# ILS Israeli new shekel                      15.050000
# INR Indian rupee                             6.610000
# ISK Icelandic króna                         14.670000
# JPY Japanese yen                            13.130000
# KRW South Korean won                        11.470000
# LTL Lithuanian litas                        11.290000
# MDL Moldovan leu                            11.290000
# MXN Mexican peso                            10.430000
# MYR Malaysian ringgit                       10.650000
# NOK Norwegian krone                         12.170000
# NZD New Zealand dollar                      12.530000
# PEN Peruvian nuevo sol                       8.560000
# PHP Philippine peso                          9.140000
# PLN Polish zloty                            10.580000
# PYG Paraguayan guaraní                      11.490000
# RON Romanian new Leu                        11.290000
# SEK Swedish krona                           14.200000
# SGD Singapore dollar                        12.810000
# THB Thai baht                               10.430000
# TRY Turkish lira                             3.000000
# TWD New Taiwan dollar                       11.900000
# UAH Ukrainian hryvnia                        8.460000
# USD US dollar                               12.490000
# UYU Urugayan peso                           12.990000
# VES sovereign bolivar                       10.990000
# ZAR South African rand                      10.050000
#
#                         Cost Per Month - Premium ($)
# Currency
# ARS Argentine peso                           9.26000
# AUD Australian dollar                       16.39000
# BGN Bulgarian lev                           13.54000
# BOB Boliviano                               13.99000
# BRL Brazilian real                           9.96000
# CAD Canadian dollar                         15.03000
# CHF Swiss franc                             26.96000
# CLP Chilean peso                            12.74000
# COP Colombian peso                           9.93000
# CRC Costa Rican colon                       15.99000
# DKK Danish krone                            19.60000
# EUR Euro                                    18.20125
# GIP Gibraltar pound                         20.32000
# GTQ Guatemalan quetzal                      13.99000
# HKD Hong Kong dollar                        11.93000
# HNL Honduran lempira                        13.99000
# HRK Croatian kuna                           13.54000
# HUF Hungarian forint                        13.78000
# IDR Indonesian rupiah                       12.96000
# ILS Israeli new shekel                      19.54000
# INR Indian rupee                             8.60000
# ISK Icelandic króna                         20.32000
# JPY Japanese yen                            17.45000
# KRW South Korean won                        14.45000
# LTL Lithuanian litas                        13.54000
# MDL Moldovan leu                            13.54000
# MXN Mexican peso                            14.24000
# MYR Malaysian ringgit                       13.02000
# NOK Norwegian krone                         17.75000
# NZD New Zealand dollar                      16.94000
# PEN Peruvian nuevo sol                      11.01000
# PHP Philippine peso                         10.93000
# PLN Polish zloty                            14.76000
# PYG Paraguayan guaraní                      14.69000
# RON Romanian new Leu                        13.54000
# SEK Swedish krona                           19.70000
# SGD Singapore dollar                        16.11000
# THB Thai baht                               12.52000
# TRY Turkish lira                             4.02000
# TWD New Taiwan dollar                       14.07000
# UAH Ukrainian hryvnia                       11.29000
# USD US dollar                               15.99000
# UYU Urugayan peso                           15.99000
# VES sovereign bolivar                       13.99000
# ZAR South African rand                      12.58000

# %%
df_all.groupby(by = 'Continent').mean()[['Cost Per Month - Basic ($)', 'Cost Per Month - Standard ($)', 'Cost Per Month - Premium ($)']]
# Out:
#                Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# Continent
# Africa                           6.260000                      10.050000
# Asia                             7.305556                      10.164444
# Europe                           9.314839                      13.452258
# North America                    7.900000                      11.454000
# Oceania                          8.320000                      12.325000
# South America                    6.388750                       9.276250
#
#                Cost Per Month - Premium ($)
# Continent
# Africa                            12.580000
# Asia                              12.794444
# Europe                            17.773226
# North America                     14.648000
# Oceania                           16.665000
# South America                     12.196250

# %%
df_all.groupby(by = 'Continent').mean()[['Cost Per Month - Basic ($)', 'Cost Per Month - Standard ($)', 'Cost Per Month - Premium ($)']]
# Out:
#                Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# Continent
# Africa                           6.260000                      10.050000
# Asia                             7.305556                      10.164444
# Europe                           9.314839                      13.452258
# North America                    7.900000                      11.454000
# Oceania                          8.320000                      12.325000
# South America                    6.388750                       9.276250
#
#                Cost Per Month - Premium ($)
# Continent
# Africa                            12.580000
# Asia                              12.794444
# Europe                            17.773226
# North America                     14.648000
# Oceania                           16.665000
# South America                     12.196250

# %% [markdown]
# ## Сколько стоит подписка относительно среднего дохода в Чехии

# %% [markdown]
# Не совсем понял, что именно требуется посчитать. Но посчитал так: стоимость подписки в Чехии деленная на средний доход во всем мире

# %%
average_income_Czechia = float(df_all.mean()[['Median Income']])

price_basic_cz = float(df_all['Cost Per Month - Basic ($)'][df_all['Country'] == 'Czechia'])/average_income_Czechia
price_standart_cz = float(df_all['Cost Per Month - Standard ($)'][df_all['Country'] == 'Czechia'])/average_income_Czechia
price_premium_cz = float(df_all['Cost Per Month - Premium ($)'][df_all['Country'] == 'Czechia'])/average_income_Czechia

print(f'Сколько стоит базовая подписка относительно среднего дохода в Чехии = {price_basic_cz}')
print(f'Сколько стоит стандартная подписка относительно среднего дохода в Чехии = {price_standart_cz}')                                                                                                        
print(f'Сколько стоит примальная подписка относительно среднего дохода в Чехии = {price_premium_cz}')
# Out:
# Сколько стоит базовая подписка относительно среднего дохода в Чехии = 0.0009095012133328304
# Сколько стоит стандартная подписка относительно среднего дохода в Чехии = 0.0011834845913017238
# Сколько стоит примальная подписка относительно среднего дохода в Чехии = 0.0014574679692706172

# %% [markdown]
# ## Какие топ-5 стран имеют самую большую доступную коллекцию сериалов?

# %%
df_library_asc = df_all.sort_values(by = 'Total Library Size', ascending = False)[['Country', 'Total Library Size']]
df_library_asc.head(5)
# Out:
#            Country  Total Library Size
# 12         Czechia                7325
# 51        Slovakia                7035
# 24         Hungary                6884
# 6         Bulgaria                6797
# 61  United Kingdom                6643

# %% [markdown]
# ## Какой процент среднего дохода россиянина будет составлять подписка Netflix?

# %%
average_income_Russia = float(df_all['Median Income'][df_all['Country'] == 'Russia'])

price_basic_ru = float(df_all['Cost Per Month - Basic ($)'][df_all['Country'] == 'Russia'])/average_income_Russia*100
price_standart_ru = float(df_all['Cost Per Month - Standard ($)'][df_all['Country'] == 'Russia'])/average_income_Russia*100
price_premium_ru = float(df_all['Cost Per Month - Premium ($)'][df_all['Country'] == 'Russia'])/average_income_Russia*100

print(f'базовая подписка = {price_basic_ru}%')
print(f'стандартная подписка = {price_standart_ru}%')                                                                                                        
print(f'премиальная подписка = {price_premium_ru}%')
# Out:
# базовая подписка = 0.14771075581395351%
# стандартная подписка = 0.19694767441860464%
# премиальная подписка = 0.24636627906976746%

# %% [markdown]
# ## На каком месте будет Россия, если отсортировать страны по эффективности подписки (Cost Per Title)

# %%
df_all['Cost Per Title B'] = df_all['Cost Per Month - Basic ($)']/df_all['Total Library Size']
df_all['Cost Per Title S'] = df_all['Cost Per Month - Standard ($)']/df_all['Total Library Size']
df_all['Cost Per Title P'] = df_all['Cost Per Month - Premium ($)']/df_all['Total Library Size']

table_cost_per_title_B = df_all.sort_values(by='Cost Per Title B',ascending=True)
table_cost_per_title_S = df_all.sort_values(by='Cost Per Title S',ascending=True)
table_cost_per_title_P = df_all.sort_values(by='Cost Per Title P',ascending=True)

print('Basic: ', table_cost_per_title_B[table_cost_per_title_B['Country'] == 'Russia'].index)
print('Standart: ', table_cost_per_title_S[table_cost_per_title_S['Country'] == 'Russia'].index)
print('Premium: ', table_cost_per_title_P[table_cost_per_title_P['Country'] == 'Russia'].index)
# Out:
# Basic:  Int64Index([48], dtype='int64')
# Standart:  Int64Index([48], dtype='int64')
# Premium:  Int64Index([48], dtype='int64')

# %% [markdown]
# Видим, что Россия находится на 48 месте по всем видам подписок

# %% [markdown]
# ## В какой стране лучше всего брать VPN для того, чтобы платить за Netflix меньше всего?

# %%
df_basic_asc = df_all.sort_values(by = 'Cost Per Month - Basic ($)', ascending = True)['Country']
df_basic_asc.head(1)
# Out:
# 59    Turkey
# Name: Country, dtype: object
